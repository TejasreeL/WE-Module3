# %% [markdown]
# <a href="https://colab.research.google.com/github/TejasreeL/WE-Module3/blob/main/Assignment3/Yahtzee.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import random

# Function to simulate rolling a single die and returning the result
def roll_die():
    return random.randint(1, 6)

# Function to roll five dice at once and return the results as a list
def roll_dice():
    return [roll_die() for _ in range(5)]

# Score calculation functions for each category
def score_ones(dice_rolls):
    return sum(d for d in dice_rolls if d == 1)

def score_twos(dice_rolls):
    return sum(d for d in dice_rolls if d == 2)

def score_threes(dice_rolls):
    return sum(d for d in dice_rolls if d == 3)

def score_fours(dice_rolls):
    return sum(d for d in dice_rolls if d == 4)

def score_fives(dice_rolls):
    return sum(d for d in dice_rolls if d == 5)

def score_sixes(dice_rolls):
    return sum(d for d in dice_rolls if d == 6)

def score_three_of_a_kind(dice_rolls):
    for num in range(1, 7):
        if dice_rolls.count(num) >= 3:
            return sum(dice_rolls)
    return 0

def score_four_of_a_kind(dice_rolls):
    for num in range(1, 7):
        if dice_rolls.count(num) >= 4:
            return sum(dice_rolls)
    return 0

def score_full_house(dice_rolls):
    counts = {dice: dice_rolls.count(dice) for dice in dice_rolls}
    if 2 in counts.values() and 3 in counts.values():
        return 25
    return 0

def score_small_straight(dice_rolls):
    sorted_dice = sorted(set(dice_rolls))
    for i in range(len(sorted_dice) - 3):
        if sorted_dice[i:i+4] == list(range(sorted_dice[i], sorted_dice[i+3]+1)):
            return 30
    return 0

def score_large_straight(dice_rolls):
    sorted_dice = sorted(set(dice_rolls))
    if len(sorted_dice) == 5 and sorted_dice[-1] - sorted_dice[0] == 4:
        return 40
    return 0

def score_chance(dice_rolls):
    return sum(dice_rolls)

def score_yahtzee(dice_rolls):
    if len(set(dice_rolls)) == 1:
        return 50
    return 0

# Main game loop
def play_game():
    players = ['Player 1', 'Player 2']  # Define players
    scorecards = {player: {} for player in players}  # Initialize scorecards for each player
    game_over = False  # Game over condition

    # Loop until the game is over
    while not game_over:
        for player in players:
            print(f"\n{player}'s turn:")
            dice = roll_dice()
            print("Current Dice Rolls:", dice)

            print("Available Categories:")
            # Print available categories here

            category = input("Choose a category to score: ")
            score = calculate_score(dice, category)

            # Update scorecard
            scorecards[player][category] = score

        # Check for end game conditions
        game_over = True  # Placeholder for end game condition check

    # Display final scores and determine the winner
    print("\nFinal Scores:")
    for player, scorecard in scorecards.items():
        print(player, ":", scorecard)
    # Determine and print the winner here

# Helper functions (optional)
def calculate_score(dice_rolls, category):
    if category == 'Ones':
        return score_ones(dice_rolls)
    elif category == 'Twos':
        return score_twos(dice_rolls)
    elif category == 'Threes':
        return score_threes(dice_rolls)
    elif category == 'Fours':
        return score_fours(dice_rolls)
    elif category == 'Fives':
        return score_fives(dice_rolls)
    elif category == 'Sixes':
        return score_sixes(dice_rolls)
    elif category == 'Three of a Kind':
        return score_three_of_a_kind(dice_rolls)
    elif category == 'Four of a Kind':
        return score_four_of_a_kind(dice_rolls)
    elif category == 'Full House':
        return score_full_house(dice_rolls)
    elif category == 'Small Straight':
        return score_small_straight(dice_rolls)
    elif category == 'Large Straight':
        return score_large_straight(dice_rolls)
    elif category == 'Chance':
        return score_chance(dice_rolls)
    elif category == 'Yahtzee':
        return score_yahtzee(dice_rolls)
    else:
        print("Invalid category.")
        return 0

# Initialization and game setup
play_game()  # Call play_game() to start the game
# Out:
# Player 1's turn:
# Current Dice Rolls: [2, 3, 6, 6, 4]
# Available Categories:
# Choose a category to score: Sixes
#
# Player 2's turn:
# Current Dice Rolls: [3, 5, 6, 6, 5]
# Available Categories:
# Choose a category to score: Chance
#
# Final Scores:
# Player 1 : {'Sixes': 12}
# Player 2 : {'Chance': 25}

# %%
import random

# Function to simulate rolling a single die and returning the result
def roll_die():
    return random.randint(1, 6)

# Function to roll five dice at once and return the results as a list
def roll_dice():
    return [roll_die() for _ in range(5)]

# Score calculation functions for each category
def score_ones(dice_rolls):
    return sum(d for d in dice_rolls if d == 1)

def score_twos(dice_rolls):
    return sum(d for d in dice_rolls if d == 2)

# Similar functions for Threes, Fours, Fives, and Sixes...
def score_threes(dice_rolls):
    return sum(d for d in dice_rolls if d == 3)

def score_fours(dice_rolls):
    return sum(d for d in dice_rolls if d == 4)

def score_fives(dice_rolls):
    return sum(d for d in dice_rolls if d == 5)

def score_sixes(dice_rolls):
    return sum(d for d in dice_rolls if d == 6)

def score_three_of_a_kind(dice_rolls):
    for num in range(1, 7):
        if dice_rolls.count(num) >= 3:
            return sum(dice_rolls)
    return 0

# Similar functions for Four of a Kind, Full House, Small Straight, Large Straight...
def score_four_of_a_kind(dice_rolls):
    for num in range(1, 7):
        if dice_rolls.count(num) >= 4:
            return sum(dice_rolls)
    return 0

def score_full_house(dice_rolls):
    counts = {dice: dice_rolls.count(dice) for dice in dice_rolls}
    if 2 in counts.values() and 3 in counts.values():
        return 25
    return 0

def score_small_straight(dice_rolls):
    sorted_dice = sorted(set(dice_rolls))
    for i in range(len(sorted_dice) - 3):
        if sorted_dice[i:i+4] == list(range(sorted_dice[i], sorted_dice[i+3]+1)):
            return 30
    return 0

def score_large_straight(dice_rolls):
    sorted_dice = sorted(set(dice_rolls))
    if len(sorted_dice) == 5 and sorted_dice[-1] - sorted_dice[0] == 4:
        return 40
    return 0

def score_chance(dice_rolls):
    return sum(dice_rolls)

def score_yahtzee(dice_rolls):
    if len(set(dice_rolls)) == 1:
        return 50
    return 0

# Main game loop
def play_game():
    players = ['Player 1', 'Player 2']  # Define players
    scorecards = {player: {} for player in players}  # Initialize scorecards for each player
    game_over = False  # Game over condition

    # Loop until the game is over
    while not game_over:
        for player in players:
            print(f"\n{player}'s turn:")
            dice = roll_dice()
            print("Current Dice Rolls:", dice)

            # Allow player to reroll specific dice
            reroll_indices = input("Enter indexes of dice to reroll (e.g., '1 3 5'). Leave empty to keep all: ").split()
            if reroll_indices:
                reroll_indices = [int(idx) - 1 for idx in reroll_indices]
                for idx in reroll_indices:
                    dice[idx] = roll_die()

            print("New Dice Rolls:", dice)

            print("Available Categories:")
            # Print available categories here

            category = input("Choose a category to score: ")
            score = calculate_score(dice, category)

            # Update scorecard
            scorecards[player][category] = score

        # Check for end game conditions
        game_over = True  # Placeholder for end game condition check

    # Display final scores and determine the winner
    print("\nFinal Scores:")
    for player, scorecard in scorecards.items():
        print(player, ":", scorecard)
    # Determine and print the winner here

# Helper functions (optional)
def calculate_score(dice_rolls, category):
    if category == 'Ones':
        return score_ones(dice_rolls)
    elif category == 'Twos':
        return score_twos(dice_rolls)
    elif category == 'Threes':
        return score_threes(dice_rolls)
    elif category == 'Fours':
        return score_fours(dice_rolls)
    elif category == 'Fives':
        return score_fives(dice_rolls)
    elif category == 'Sixes':
        return score_sixes(dice_rolls)
    elif category == 'Three of a Kind':
        return score_three_of_a_kind(dice_rolls)
    elif category == 'Four of a Kind':
        return score_four_of_a_kind(dice_rolls)
    elif category == 'Full House':
        return score_full_house(dice_rolls)
    elif category == 'Small Straight':
        return score_small_straight(dice_rolls)
    elif category == 'Large Straight':
        return score_large_straight(dice_rolls)
    elif category == 'Chance':
        return score_chance(dice_rolls)
    elif category == 'Yahtzee':
        return score_yahtzee(dice_rolls)
    else:
        print("Invalid category.")
        return 0

# Initialization and game setup
play_game()  # Call play_game() to start the game
# Out:
# Player 1's turn:
# Current Dice Rolls: [6, 4, 6, 1, 5]
# Enter indexes of dice to reroll (e.g., '1 3 5'). Leave empty to keep all: 1 3 4
# New Dice Rolls: [3, 4, 5, 5, 5]
# Available Categories:
# Choose a category to score: Fives
#
# Player 2's turn:
# Current Dice Rolls: [1, 6, 5, 2, 5]
# Enter indexes of dice to reroll (e.g., '1 3 5'). Leave empty to keep all:
# New Dice Rolls: [1, 6, 5, 2, 5]
# Available Categories:
# Choose a category to score: Chance
#
# Final Scores:
# Player 1 : {'Fives': 15}
# Player 2 : {'Chance': 19}

# %%
import random

# Function to simulate rolling a single die and returning the result
def roll_die():
    return random.randint(1, 6)

# Function to roll five dice at once and return the results as a list
def roll_dice():
    return [roll_die() for _ in range(5)]

# Score calculation functions for each category
def score_ones(dice_rolls):
    return sum(d for d in dice_rolls if d == 1)

def score_twos(dice_rolls):
    return sum(d for d in dice_rolls if d == 2)

# Similar functions for Threes, Fours, Fives, and Sixes...
def score_threes(dice_rolls):
    return sum(d for d in dice_rolls if d == 3)

def score_fours(dice_rolls):
    return sum(d for d in dice_rolls if d == 4)

def score_fives(dice_rolls):
    return sum(d for d in dice_rolls if d == 5)

def score_sixes(dice_rolls):
    return sum(d for d in dice_rolls if d == 6)

def score_three_of_a_kind(dice_rolls):
    for num in range(1, 7):
        if dice_rolls.count(num) >= 3:
            return sum(dice_rolls)
    return 0

# Similar functions for Four of a Kind, Full House, Small Straight, Large Straight...
def score_four_of_a_kind(dice_rolls):
    for num in range(1, 7):
        if dice_rolls.count(num) >= 4:
            return sum(dice_rolls)
    return 0

def score_full_house(dice_rolls):
    counts = {dice: dice_rolls.count(dice) for dice in dice_rolls}
    if 2 in counts.values() and 3 in counts.values():
        return 25
    return 0

def score_small_straight(dice_rolls):
    sorted_dice = sorted(set(dice_rolls))
    for i in range(len(sorted_dice) - 3):
        if sorted_dice[i:i+4] == list(range(sorted_dice[i], sorted_dice[i+3]+1)):
            return 30
    return 0

def score_large_straight(dice_rolls):
    sorted_dice = sorted(set(dice_rolls))
    if len(sorted_dice) == 5 and sorted_dice[-1] - sorted_dice[0] == 4:
        return 40
    return 0

def score_chance(dice_rolls):
    return sum(dice_rolls)

def score_yahtzee(dice_rolls):
    if len(set(dice_rolls)) == 1:
        return 50
    return 0

# Main game loop
def play_game():
    players = ['Player 1', 'Player 2']  # Define players
    scorecards = {player: {} for player in players}  # Initialize scorecards for each player
    game_over = False  # Game over condition

    # Loop until the game is over
    while not game_over:
        for player in players:
            print(f"\n{player}'s turn:")
            dice = roll_dice()
            print("Current Dice Rolls:", dice)

            # Two reroll options for each player
            for _ in range(2):
                reroll_indices = input("Enter indexes of dice to reroll (e.g., '1 3 5'). Leave empty to keep all: ").split()
                if reroll_indices:
                    reroll_indices = [int(idx) - 1 for idx in reroll_indices]
                    for idx in reroll_indices:
                        dice[idx] = roll_die()

                print("New Dice Rolls:", dice)

            print("Available Categories:")
            # Print available categories here

            category = input("Choose a category to score: ")
            score = calculate_score(dice, category)

            # Update scorecard
            scorecards[player][category] = score

        # Check for end game conditions
        game_over = True  # Placeholder for end game condition check

    # Display final scores and determine the winner
    print("\nFinal Scores:")
    for player, scorecard in scorecards.items():
        print(player, ":", scorecard)
    # Determine and print the winner here

# Helper functions (optional)
def calculate_score(dice_rolls, category):
    if category == 'Ones':
        return score_ones(dice_rolls)
    elif category == 'Twos':
        return score_twos(dice_rolls)
    elif category == 'Threes':
        return score_threes(dice_rolls)
    elif category == 'Fours':
        return score_fours(dice_rolls)
    elif category == 'Fives':
        return score_fives(dice_rolls)
    elif category == 'Sixes':
        return score_sixes(dice_rolls)
    elif category == 'Three of a Kind':
        return score_three_of_a_kind(dice_rolls)
    elif category == 'Four of a Kind':
        return score_four_of_a_kind(dice_rolls)
    elif category == 'Full House':
        return score_full_house(dice_rolls)
    elif category == 'Small Straight':
        return score_small_straight(dice_rolls)
    elif category == 'Large Straight':
        return score_large_straight(dice_rolls)
    elif category == 'Chance':
        return score_chance(dice_rolls)
    elif category == 'Yahtzee':
        return score_yahtzee(dice_rolls)
    else:
        print("Invalid category.")
        return 0

# Initialization and game setup
play_game()  # Call play_game() to start the game
# Out:
# Player 1's turn:
# Current Dice Rolls: [3, 2, 5, 2, 4]
# Enter indexes of dice to reroll (e.g., '1 3 5'). Leave empty to keep all: 1 3 5
# New Dice Rolls: [4, 2, 1, 2, 1]
# Enter indexes of dice to reroll (e.g., '1 3 5'). Leave empty to keep all: 3 5
# New Dice Rolls: [4, 2, 5, 2, 4]
# Available Categories:
# Choose a category to score: Fours
#
# Player 2's turn:
# Current Dice Rolls: [4, 5, 3, 1, 5]
# Enter indexes of dice to reroll (e.g., '1 3 5'). Leave empty to keep all: 1 3 4
# New Dice Rolls: [4, 5, 3, 1, 5]
# Enter indexes of dice to reroll (e.g., '1 3 5'). Leave empty to keep all: 1 3 4
# New Dice Rolls: [5, 5, 5, 1, 5]
# Available Categories:
# Choose a category to score: Fives
#
# Final Scores:
# Player 1 : {'Fours': 8}
# Player 2 : {'Fives': 20}

# %%
import random

# Function to simulate rolling a single die and returning the result
def roll_die():
    return random.randint(1, 6)

# Function to roll five dice at once and return the results as a list
def roll_dice():
    return [roll_die() for _ in range(5)]

# Score calculation functions for each category
def score_ones(dice_rolls):
    return sum(d for d in dice_rolls if d == 1)

def score_twos(dice_rolls):
    return sum(d for d in dice_rolls if d == 2)

# Similar functions for Threes, Fours, Fives, and Sixes...
def score_threes(dice_rolls):
    return sum(d for d in dice_rolls if d == 3)

def score_fours(dice_rolls):
    return sum(d for d in dice_rolls if d == 4)

def score_fives(dice_rolls):
    return sum(d for d in dice_rolls if d == 5)

def score_sixes(dice_rolls):
    return sum(d for d in dice_rolls if d == 6)

def score_three_of_a_kind(dice_rolls):
    for num in range(1, 7):
        if dice_rolls.count(num) >= 3:
            return sum(dice_rolls)
    return 0

# Similar functions for Four of a Kind, Full House, Small Straight, Large Straight...
def score_four_of_a_kind(dice_rolls):
    for num in range(1, 7):
        if dice_rolls.count(num) >= 4:
            return sum(dice_rolls)
    return 0

def score_full_house(dice_rolls):
    counts = {dice: dice_rolls.count(dice) for dice in dice_rolls}
    if 2 in counts.values() and 3 in counts.values():
        return 25
    return 0

def score_small_straight(dice_rolls):
    sorted_dice = sorted(set(dice_rolls))
    for i in range(len(sorted_dice) - 3):
        if sorted_dice[i:i+4] == list(range(sorted_dice[i], sorted_dice[i+3]+1)):
            return 30
    return 0

def score_large_straight(dice_rolls):
    sorted_dice = sorted(set(dice_rolls))
    if len(sorted_dice) == 5 and sorted_dice[-1] - sorted_dice[0] == 4:
        return 40
    return 0

def score_chance(dice_rolls):
    return sum(dice_rolls)

def score_yahtzee(dice_rolls):
    if len(set(dice_rolls)) == 1:
        return 50
    return 0

# Main game loop
def play_game():
    players = ['Player 1', 'Player 2']  # Define players
    scorecards = {player: {} for player in players}  # Initialize scorecards for each player
    rounds = 13  # Number of rounds
    game_over = False  # Game over condition

    # Loop until the game is over
    for round_num in range(1, rounds + 1):
        print("\nRound", round_num)
        for player in players:
            print(f"\n{player}'s turn:")
            dice = roll_dice()
            print("Current Dice Rolls:", dice)

            # Allow player to reroll specific dice
            for _ in range(2):  # Two chances to reroll
                reroll_indices = input("Enter indexes of dice to reroll (e.g., '1 3 5'). Leave empty to keep all: ").split()
                if reroll_indices:
                    reroll_indices = [int(idx) - 1 for idx in reroll_indices]
                    for idx in reroll_indices:
                        dice[idx] = roll_die()

                print("New Dice Rolls:", dice)

            print("Available Categories:")
            # Print available categories here

            category = input("Choose a category to score: ")
            score = calculate_score(dice, category)

            # Update scorecard
            scorecards[player][category] = score

    # Display final scores and determine the winner
    print("\nFinal Scores:")
    for player, scorecard in scorecards.items():
        print(player, ":", scorecard)
    # Determine and print the winner here

# Helper functions (optional)
def calculate_score(dice_rolls, category):
    if category == 'Ones':
        return score_ones(dice_rolls)
    elif category == 'Twos':
        return score_twos(dice_rolls)
    elif category == 'Threes':
        return score_threes(dice_rolls)
    elif category == 'Fours':
        return score_fours(dice_rolls)
    elif category == 'Fives':
        return score_fives(dice_rolls)
    elif category == 'Sixes':
        return score_sixes(dice_rolls)
    elif category == 'Three of a Kind':
        return score_three_of_a_kind(dice_rolls)
    elif category == 'Four of a Kind':
        return score_four_of_a_kind(dice_rolls)
    elif category == 'Full House':
        return score_full_house(dice_rolls)
    elif category == 'Small Straight':
        return score_small_straight(dice_rolls)
    elif category == 'Large Straight':
        return score_large_straight(dice_rolls)
    elif category == 'Chance':
        return score_chance(dice_rolls)
    elif category == 'Yahtzee':
        return score_yahtzee(dice_rolls)
    else:
        print("Invalid category.")
        return 0

# Initialization and game setup
play_game()  # Call play_game() to start the game
# Out:
# Round 1
#
# Player 1's turn:
# Current Dice Rolls: [5, 3, 1, 4, 3]
# Enter indexes of dice to reroll (e.g., '1 3 5'). Leave empty to keep all: 3 4
# New Dice Rolls: [5, 3, 1, 4, 3]
# Enter indexes of dice to reroll (e.g., '1 3 5'). Leave empty to keep all: 3 4
# New Dice Rolls: [5, 3, 1, 6, 3]
# Available Categories:
# Choose a category to score: Chance
#
# Player 2's turn:
# Current Dice Rolls: [2, 1, 3, 4, 4]
# Enter indexes of dice to reroll (e.g., '1 3 5'). Leave empty to keep all: 1 2 3
# New Dice Rolls: [5, 3, 3, 4, 4]
# Enter indexes of dice to reroll (e.g., '1 3 5'). Leave empty to keep all: 1
# New Dice Rolls: [1, 3, 3, 4, 4]
# Available Categories:
# Choose a category to score: Chance
#
# Round 2
#
# Player 1's turn:
# Current Dice Rolls: [4, 5, 5, 2, 5]
# Enter indexes of dice to reroll (e.g., '1 3 5'). Leave empty to keep all: 1 4
# New Dice Rolls: [6, 5, 5, 1, 5]
# Enter indexes of dice to reroll (e.g., '1 3 5'). Leave empty to keep all: 4
# New Dice Rolls: [6, 5, 5, 1, 5]
# Available Categories:
# Choose a category to score: Three of a Kind
#
# Player 2's turn:
# Current Dice Rolls: [6, 3, 1, 6, 5]
# Enter indexes of dice to reroll (e.g., '1 3 5'). Leave empty to keep all: 2 3 5
# New Dice Rolls: [6, 5, 4, 6, 5]
# Enter indexes of dice to reroll (e.g., '1 3 5'). Leave empty to keep all: 3
# New Dice Rolls: [6, 5, 6, 6, 5]
# Available Categories:
# Choose a category to score: Three of a Kind
#
# Round 3
#
# Player 1's turn:
# Current Dice Rolls: [2, 2, 6, 6, 4]
# Enter indexes of dice to reroll (e.g., '1 3 5'). Leave empty to keep all: 5
# New Dice Rolls: [2, 2, 6, 6, 2]
# Enter indexes of dice to reroll (e.g., '1 3 5'). Leave empty to keep all:
# New Dice Rolls: [2, 2, 6, 6, 2]
# Available Categories:
# Choose a category to score: Three of a Kind
#
# Player 2's turn:
# Current Dice Rolls: [5, 1, 3, 6, 1]
# Enter indexes of dice to reroll (e.g., '1 3 5'). Leave empty to keep all:
# New Dice Rolls: [5, 1, 3, 6, 1]
# Enter indexes of dice to reroll (e.g., '1 3 5'). Leave empty to keep all:
# New Dice Rolls: [5, 1, 3, 6, 1]
# Available Categories:
# Choose a category to score: Chance
#
# Round 4
#
# Player 1's turn:
# Current Dice Rolls: [2, 5, 6, 6, 3]
# Enter indexes of dice to reroll (e.g., '1 3 5'). Leave empty to keep all: 1 2 5
# New Dice Rolls: [1, 1, 6, 6, 6]
# Enter indexes of dice to reroll (e.g., '1 3 5'). Leave empty to keep all: 1 2
# New Dice Rolls: [4, 2, 6, 6, 6]
# Available Categories:
# Choose a category to score: Three of a Kind
#
# Player 2's turn:
# Current Dice Rolls: [2, 3, 1, 1, 1]
# Enter indexes of dice to reroll (e.g., '1 3 5'). Leave empty to keep all: 1 2 3 4 5
# New Dice Rolls: [5, 2, 2, 4, 4]
# Enter indexes of dice to reroll (e.g., '1 3 5'). Leave empty to keep all: 1
# New Dice Rolls: [5, 2, 2, 4, 4]
# Available Categories:
# Choose a category to score: Chance
#
# Round 5
#
# Player 1's turn:
# Current Dice Rolls: [2, 5, 4, 6, 1]
# Enter indexes of dice to reroll (e.g., '1 3 5'). Leave empty to keep all: 1 3 5
# New Dice Rolls: [1, 5, 3, 6, 3]
# Enter indexes of dice to reroll (e.g., '1 3 5'). Leave empty to keep all: 1
# New Dice Rolls: [2, 5, 3, 6, 3]
# Available Categories:
# Choose a category to score: Chance
#
# Player 2's turn:
# Current Dice Rolls: [4, 2, 6, 2, 1]
# Enter indexes of dice to reroll (e.g., '1 3 5'). Leave empty to keep all: 3 5
# New Dice Rolls: [4, 2, 4, 2, 5]
# Enter indexes of dice to reroll (e.g., '1 3 5'). Leave empty to keep all: 5
# New Dice Rolls: [4, 2, 4, 2, 4]
# Available Categories:
# Choose a category to score: Full House
#
# Round 6
#
# Player 1's turn:
# Current Dice Rolls: [2, 4, 2, 6, 3]
# Enter indexes of dice to reroll (e.g., '1 3 5'). Leave empty to keep all: 2 5
# New Dice Rolls: [2, 5, 2, 6, 6]
# Enter indexes of dice to reroll (e.g., '1 3 5'). Leave empty to keep all: 2
# New Dice Rolls: [2, 2, 2, 6, 6]
# Available Categories:
# Choose a category to score: Full House
#
# Player 2's turn:
# Current Dice Rolls: [2, 1, 4, 3, 1]
# Enter indexes of dice to reroll (e.g., '1 3 5'). Leave empty to keep all:
# New Dice Rolls: [2, 1, 4, 3, 1]
# Enter indexes of dice to reroll (e.g., '1 3 5'). Leave empty to keep all:
# New Dice Rolls: [2, 1, 4, 3, 1]
# Available Categories:
# Choose a category to score: Chance
#
# Round 7
#
# Player 1's turn:
# Current Dice Rolls: [4, 5, 2, 5, 5]
# Enter indexes of dice to reroll (e.g., '1 3 5'). Leave empty to keep all: 1 3
# New Dice Rolls: [6, 5, 4, 5, 5]
# Enter indexes of dice to reroll (e.g., '1 3 5'). Leave empty to keep all: 3
# New Dice Rolls: [6, 5, 6, 5, 5]
# Available Categories:
# Choose a category to score: Full House
#
# Player 2's turn:
# Current Dice Rolls: [3, 6, 6, 1, 1]
# Enter indexes of dice to reroll (e.g., '1 3 5'). Leave empty to keep all: 1 4 5
# New Dice Rolls: [3, 6, 6, 2, 6]
# Enter indexes of dice to reroll (e.g., '1 3 5'). Leave empty to keep all: 4
# New Dice Rolls: [3, 6, 6, 6, 6]
# Available Categories:
# Choose a category to score: Four of a Kind
#
# Round 8
#
# Player 1's turn:
# Current Dice Rolls: [2, 4, 6, 5, 1]
# Enter indexes of dice to reroll (e.g., '1 3 5'). Leave empty to keep all: 1 2 3 4 5
# New Dice Rolls: [4, 2, 4, 2, 3]
# Enter indexes of dice to reroll (e.g., '1 3 5'). Leave empty to keep all: 5
# New Dice Rolls: [4, 2, 4, 2, 1]
# Available Categories:
# Choose a category to score: Chance
#
# Player 2's turn:
# Current Dice Rolls: [2, 1, 4, 3, 6]
# Enter indexes of dice to reroll (e.g., '1 3 5'). Leave empty to keep all: 5
# New Dice Rolls: [2, 1, 4, 3, 5]
# Enter indexes of dice to reroll (e.g., '1 3 5'). Leave empty to keep all:
# New Dice Rolls: [2, 1, 4, 3, 5]
# Available Categories:
# Choose a category to score: Large Straight
#
# Round 9
#
# Player 1's turn:
# Current Dice Rolls: [5, 5, 2, 3, 3]
# Enter indexes of dice to reroll (e.g., '1 3 5'). Leave empty to keep all: 3
# New Dice Rolls: [5, 5, 6, 3, 3]
# Enter indexes of dice to reroll (e.g., '1 3 5'). Leave empty to keep all:
# New Dice Rolls: [5, 5, 6, 3, 3]
# Available Categories:
# Choose a category to score: Chance
#
# Player 2's turn:
# Current Dice Rolls: [1, 4, 3, 3, 1]
# Enter indexes of dice to reroll (e.g., '1 3 5'). Leave empty to keep all: 1 2 5
# New Dice Rolls: [5, 3, 3, 3, 2]
# Enter indexes of dice to reroll (e.g., '1 3 5'). Leave empty to keep all: 1 5
# New Dice Rolls: [2, 3, 3, 3, 5]
# Available Categories:
# Choose a category to score: Three of a Kind
#
# Round 10
#
# Player 1's turn:
# Current Dice Rolls: [3, 6, 5, 3, 5]
# Enter indexes of dice to reroll (e.g., '1 3 5'). Leave empty to keep all: 2
# New Dice Rolls: [3, 5, 5, 3, 5]
# Enter indexes of dice to reroll (e.g., '1 3 5'). Leave empty to keep all:
# New Dice Rolls: [3, 5, 5, 3, 5]
# Available Categories:
# Choose a category to score: Full House
#
# Player 2's turn:
# Current Dice Rolls: [4, 3, 6, 5, 3]
# Enter indexes of dice to reroll (e.g., '1 3 5'). Leave empty to keep all: 1 4
# New Dice Rolls: [2, 3, 6, 1, 3]
# Enter indexes of dice to reroll (e.g., '1 3 5'). Leave empty to keep all: 1 4
# New Dice Rolls: [4, 3, 6, 4, 3]
# Available Categories:
# Choose a category to score: Chance
#
# Round 11
#
# Player 1's turn:
# Current Dice Rolls: [2, 6, 6, 3, 2]
# Enter indexes of dice to reroll (e.g., '1 3 5'). Leave empty to keep all: 1 4 5
# New Dice Rolls: [6, 6, 6, 1, 2]
# Enter indexes of dice to reroll (e.g., '1 3 5'). Leave empty to keep all: 4 5
# New Dice Rolls: [6, 6, 6, 2, 6]
# Available Categories:
# Choose a category to score: Four of a Kind
#
# Player 2's turn:
# Current Dice Rolls: [6, 6, 2, 2, 5]
# Enter indexes of dice to reroll (e.g., '1 3 5'). Leave empty to keep all: 5
# New Dice Rolls: [6, 6, 2, 2, 2]
# Enter indexes of dice to reroll (e.g., '1 3 5'). Leave empty to keep all:
# New Dice Rolls: [6, 6, 2, 2, 2]
# Available Categories:
# Choose a category to score: Full House
#
# Round 12
#
# Player 1's turn:
# Current Dice Rolls: [6, 4, 3, 1, 4]
# Enter indexes of dice to reroll (e.g., '1 3 5'). Leave empty to keep all: 1 3 4
# New Dice Rolls: [3, 4, 4, 5, 4]
# Enter indexes of dice to reroll (e.g., '1 3 5'). Leave empty to keep all: 1 4
# New Dice Rolls: [3, 4, 4, 6, 4]
# Available Categories:
# Choose a category to score: Three of a Kind'
# Invalid category.
#
# Player 2's turn:
# Current Dice Rolls: [4, 3, 2, 5, 6]
# Enter indexes of dice to reroll (e.g., '1 3 5'). Leave empty to keep all: 1 2 3 4
# New Dice Rolls: [1, 2, 6, 5, 6]
# Enter indexes of dice to reroll (e.g., '1 3 5'). Leave empty to keep all: 1 2 4
# New Dice Rolls: [4, 2, 6, 6, 6]
# Available Categories:
# Choose a category to score: Three of a Kind
#
# Round 13
#
# Player 1's turn:
# Current Dice Rolls: [1, 2, 4, 5, 4]
# Enter indexes of dice to reroll (e.g., '1 3 5'). Leave empty to keep all: 1 2 4
# New Dice Rolls: [2, 2, 4, 2, 4]
# Enter indexes of dice to reroll (e.g., '1 3 5'). Leave empty to keep all: 3 5
# New Dice Rolls: [2, 2, 6, 2, 4]
# Available Categories:
# Choose a category to score: Three of a Kind
#
# Player 2's turn:
# Current Dice Rolls: [6, 5, 4, 1, 1]
# Enter indexes of dice to reroll (e.g., '1 3 5'). Leave empty to keep all: 1 2 3
# New Dice Rolls: [3, 5, 6, 1, 1]
# Enter indexes of dice to reroll (e.g., '1 3 5'). Leave empty to keep all: 1 2 3
# New Dice Rolls: [6, 1, 5, 1, 1]
# Available Categories:
# Choose a category to score: Three of a Kind
#
# Final Scores:
# Player 1 : {'Chance': 22, 'Three of a Kind': 16, 'Full House': 25, 'Four of a Kind': 26, "Three of a Kind'": 0}
# Player 2 : {'Chance': 20, 'Three of a Kind': 14, 'Full House': 25, 'Four of a Kind': 27, 'Large Straight': 40}

# %%
def max_score_category(dice_rolls):
    categories = {
        "Ones": sum(d for d in dice_rolls if d == 1),
        "Twos": sum(d for d in dice_rolls if d == 2),
        "Threes": sum(d for d in dice_rolls if d == 3),
        "Fours": sum(d for d in dice_rolls if d == 4),
        "Fives": sum(d for d in dice_rolls if d == 5),
        "Sixes": sum(d for d in dice_rolls if d == 6),
        "Four of a Kind": sum(dice_rolls) if any(dice_rolls.count(num) >= 4 for num in dice_rolls) else 0,
        "Three of a Kind": sum(dice_rolls) if any(dice_rolls.count(num) >= 3 for num in dice_rolls) else 0,
        "Full House": 25 if any(sorted(dice_rolls) == [a] * 3 + [b] * 2 for a in set(dice_rolls) for b in set(dice_rolls) if a != b) else 0,
        "Small Straight": 30 if len(set(dice_rolls)) >= 4 and ((1 in dice_rolls and 2 in dice_rolls and 3 in dice_rolls and 4 in dice_rolls) or (2 in dice_rolls and 3 in dice_rolls and 4 in dice_rolls and 5 in dice_rolls) or (3 in dice_rolls and 4 in dice_rolls and 5 in dice_rolls and 6 in dice_rolls)) else 0,
        "Large Straight": 40 if sorted(dice_rolls) in [[1, 2, 3, 4, 5], [2, 3, 4, 5, 6]] else 0,
        "Chance": sum(dice_rolls),
        "Yahtzee": 50 if len(set(dice_rolls)) == 1 else 0
    }
    max_score = max(categories.values())
    max_category = [k for k, v in categories.items() if v == max_score][0]
    return max_category, max_score

# Example usage:
dice_rolls = [1, 1, 1, 2, 1]
category, score = max_score_category(dice_rolls)
print("Maximum score category:", category)
print("Score:", score)

dice_rolls = [1, 1, 1, 1, 1]
category, score = max_score_category(dice_rolls)
print("Maximum score category:", category)
print("Score:", score)

dice_rolls = [1, 1, 1, 2, 2]
category, score = max_score_category(dice_rolls)
print("Maximum score category:", category)
print("Score:", score)

dice_rolls = [1, 2, 4, 5, 3]
category, score = max_score_category(dice_rolls)
print("Maximum score category:", category)
print("Score:", score)

dice_rolls = [1, 2, 4, 3, 6]
category, score = max_score_category(dice_rolls)
print("Maximum score category:", category)
print("Score:", score)
# Out:
# Maximum score category: Four of a Kind
# Score: 6
# Maximum score category: Yahtzee
# Score: 50
# Maximum score category: Full House
# Score: 25
# Maximum score category: Large Straight
# Score: 40
# Maximum score category: Small Straight
# Score: 30
